# %%
# Operate from the parent directory
# This allows us to import modules from the parent directory
import os
os.chdir("..")

import time
from pose_encoder.advanced_pose_encoder import AdvancedPoseEncoder
from dataset.dataset import *
import utils.utils as utils
from torch.utils.data import DataLoader
from tqdm import tqdm
import utils.animation.visualisation.new.animation_visualisation as animation_visualisation
from torch.amp import autocast

device = utils.get_device()

# %%
animation_visualisation.init_visualization()
# Out:
# Viewer URL: http://localhost:8000/utils/animation/visualisation/new/animation_viewer4.html?wsport=8700
# <iframe src="http://localhost:8000/utils/animation/visualisation/new/animation_viewer4.html?wsport=8700" width="512" height="512" frameborder="0"></iframe><br>

# %%
dataset = GPUDataset(
    consolidated_file="dataset/genea2023_dataset/val/main-agent/advanced_encoder/consolidated.npz",
    seq_length=100, # For testing
    seed_length=0,
    batch_size=1,
    epoch_length=100,
    loading_encoded_data = True
)

with autocast(device_type=device.type, dtype=torch.bfloat16):
    autoencoder_model = AdvancedPoseEncoder.load_from_checkpoint("advanced_pose_encoder_ik_pca_64")

    data_loader = DataLoader(
        dataset,
        batch_size=1,
        shuffle=False,
        num_workers=0
    )

    progress_bar = tqdm(data_loader, desc=f'Testing', leave=True)
    for i, batch_data in enumerate(progress_bar):
        with torch.no_grad():
            
            gesture_sequence, _, audio_features, main_agent_id_one_hot = [
                item.squeeze(0).to(device) for item in batch_data
            ]

            if dataset.loading_encoded_data:
                gesture_sequence = autoencoder_model.decode(gesture_sequence)

            gesture_sequence = dataset.skeleton.denormalize_poses(gesture_sequence)

            # Send every frame to the visualizer
            for frame in gesture_sequence.squeeze(0):
                animation_visualisation.send_pose(frame.cpu(),dataset.skeleton)
                time.sleep(1.0 / 30.0)  # Assuming 30 FPS
# Out:
# Initializing GPU-resident dataset on cuda
# Loading data from dataset/genea2023_dataset/val/main-agent/advanced_encoder/consolidated.npz directly to GPU...
# Data loaded to GPU. Gesture shape: torch.Size([75600, 64]), Audio shape: torch.Size([75600, 37])
# Found 71541 valid starting points for windows
# Dataset initialization complete!
#
# Unhandled bones that will use identity rotation:
#   b_r_arm_twist: indices 57-62
#   b_r_wrist_twist: indices 69-74
#   b_l_arm_twist: indices 189-194
#   b_l_wrist_twist: indices 201-206
# Testing:   0%|          | 0/100 [00:00<?, ?it/s]
# === Pose Encoder Profiling Information ===
# initialization                : 0.00 ms
# preserved_components          : 0.00 ms
# auto_encoded_components       : 1.00 ms
# denormalization               : 2.00 ms
# unhandled_indices             : 0.00 ms
# identity_rotations            : 0.00 ms
# world_positions               : 3.00 ms
# ik_processing                 : 34.38 ms
# world_preserve_after_ik       : 1.00 ms
# final_normalization           : 1.00 ms
# Testing:   1%|          | 1/100 [00:03<06:34,  3.99s/it]
# === Pose Encoder Profiling Information ===
# initialization                : 0.00 ms
# preserved_components          : 0.00 ms
# auto_encoded_components       : 1.00 ms
# denormalization               : 0.00 ms
# unhandled_indices             : 0.00 ms
# identity_rotations            : 0.00 ms
# world_positions               : 2.01 ms
# ik_processing                 : 5.00 ms
# world_preserve_after_ik       : 1.00 ms
# final_normalization           : 1.00 ms
# Testing:   2%|▏         | 2/100 [00:07<06:29,  3.97s/it]
# === Pose Encoder Profiling Information ===
# initialization                : 0.00 ms
# preserved_components          : 0.00 ms
# auto_encoded_components       : 1.00 ms
# denormalization               : 0.00 ms
# unhandled_indices             : 0.00 ms
# identity_rotations            : 1.00 ms
# world_positions               : 2.00 ms
# ik_processing                 : 10.00 ms
# world_preserve_after_ik       : 1.00 ms
# final_normalization           : 1.00 ms
# Testing:   3%|▎         | 3/100 [00:11<06:26,  3.98s/it]
# === Pose Encoder Profiling Information ===
# initialization                : 0.00 ms
# preserved_components          : 0.00 ms
# auto_encoded_components       : 1.00 ms
# denormalization               : 0.00 ms
# unhandled_indices             : 0.00 ms
# identity_rotations            : 0.00 ms
# world_positions               : 2.00 ms
# ik_processing                 : 5.04 ms
# world_preserve_after_ik       : 7.00 ms
# final_normalization           : 7.00 ms
# Testing:   4%|▍         | 4/100 [00:15<06:21,  3.98s/it]
# === Pose Encoder Profiling Information ===
# initialization                : 0.00 ms
# preserved_components          : 0.00 ms
# auto_encoded_components       : 1.00 ms
# denormalization               : 0.00 ms
# unhandled_indices             : 0.00 ms
# identity_rotations            : 0.00 ms
# world_positions               : 3.00 ms
# ik_processing                 : 10.00 ms
# world_preserve_after_ik       : 1.00 ms
# final_normalization           : 2.00 ms
# Testing:   5%|▌         | 5/100 [00:19<06:17,  3.97s/it]
# === Pose Encoder Profiling Information ===
# initialization                : 0.00 ms
# preserved_components          : 0.00 ms
# auto_encoded_components       : 1.00 ms
# denormalization               : 0.00 ms
# unhandled_indices             : 0.00 ms
# identity_rotations            : 0.00 ms
# world_positions               : 2.00 ms
# ik_processing                 : 10.00 ms
# world_preserve_after_ik       : 1.00 ms
# final_normalization           : 1.00 ms
# Testing:   6%|▌         | 6/100 [00:23<06:12,  3.97s/it]
# === Pose Encoder Profiling Information ===
# initialization                : 0.00 ms
# preserved_components          : 1.30 ms
# auto_encoded_components       : 0.00 ms
# denormalization               : 0.00 ms
# unhandled_indices             : 0.00 ms
# identity_rotations            : 0.00 ms
# world_positions               : 2.51 ms
# ik_processing                 : 5.00 ms
# world_preserve_after_ik       : 2.00 ms
# final_normalization           : 2.00 ms
# Testing:   7%|▋         | 7/100 [00:27<06:08,  3.96s/it]
# === Pose Encoder Profiling Information ===
# initialization                : 0.00 ms
# preserved_components          : 1.32 ms
# auto_encoded_components       : 0.00 ms
# denormalization               : 0.00 ms
# unhandled_indices             : 0.00 ms
# identity_rotations            : 1.00 ms
# world_positions               : 2.00 ms
# ik_processing                 : 11.51 ms
# world_preserve_after_ik       : 1.00 ms
# final_normalization           : 1.00 ms
# Testing:   7%|▋         | 7/100 [00:28<06:23,  4.12s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 36
#      34 for frame in gesture_sequence.squeeze(0):
#      35     animation_visualisation.send_pose(frame.cpu(),dataset.skeleton)
# ---> 36     time.sleep(1.0 / 30.0)  # Assuming 30 FPS
#
# KeyboardInterrupt:
